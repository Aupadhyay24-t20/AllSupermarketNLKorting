# %%
import pandas as pd
import re

# %%
df = pd.read_json("../scraping/j_raw_deals_2.json")

# %%
df
# Out:
#                                               product  \
# 0   Frambozen of Hollandse aardbeien [Kompas JumRo...
# 1           Combikorting fruit [Kompas JumRouterLink]
# 2           Jumbo roerbakmixen [Kompas JumRouterLink]
# 3               Alle Pink Lady [Kompas JumRouterLink]
# 4   Jumbo fijnproevers asperges geschild of witte ...
# ..                                                ...
# 92              Alle Pink Lady [Kompas JumRouterLink]
# 93                     Baileys [Kompas JumRouterLink]
# 94  Licor Beirao, Southern Comfort, Grand Marnier ...
# 95                     Bacardi [Kompas JumRouterLink]
# 96  Welke biermerken zijn bij jouw Jumbo in de aan...
#
#                                discount  \
# 0                           2 voor 6,00
# 1              Combikorting 2 voor 4,50
# 2                           2 voor 3,50
# 3                             voor 2,49
# 4                             voor 4,99
# ..                                  ...
# 92    Alleen in de winkel 2,49 per kilo
# 93  Alleen in de slijterij 4,00 korting
# 94  Alleen in de slijterij 4,00 korting
# 95    Alleen in de slijterij voor 14,99
# 96                       2e halve prijs
#
#                                                  link  store  \
# 0   https://www.jumbo.com/aanbiedingen/frambozen-o...  Jumbo
# 1   https://www.jumbo.com/aanbiedingen/combikortin...  Jumbo
# 2   https://www.jumbo.com/aanbiedingen/jumbo-roerb...  Jumbo
# 3   https://www.jumbo.com/aanbiedingen/alle-pink-l...  Jumbo
# 4   https://www.jumbo.com/aanbiedingen/jumbo-fijnp...  Jumbo
# ..                                                ...    ...
# 92  https://www.jumbo.com/aanbiedingen/alle-pink-l...  Jumbo
# 93  https://www.jumbo.com/aanbiedingen/baileys/301...  Jumbo
# 94  https://www.jumbo.com/aanbiedingen/licor-beira...  Jumbo
# 95  https://www.jumbo.com/aanbiedingen/bacardi/301...  Jumbo
# 96        https://www.jumbo.com/acties/bieraanbieding  Jumbo
#
#                       date
# 0       wo 6 t/m di 12 mei
# 1       wo 6 t/m di 12 mei
# 2       wo 6 t/m di 12 mei
# 3       wo 6 t/m di 12 mei
# 4       wo 6 t/m di 12 mei
# ..                     ...
# 92      wo 6 t/m di 12 mei
# 93      wo 6 t/m di 12 mei
# 94      wo 6 t/m di 12 mei
# 95      wo 6 t/m di 12 mei
# 96  wo 4 feb t/m wo 30 dec
#
# [97 rows x 5 columns]

# %%
def wo_remove(text):
    remove = "wo"
    remove_2 = "di"
    text = text.replace(remove, "")
    text = text.replace(remove_2, "").strip()
    return text

df["date"] = df["date"].apply(wo_remove)
df
# Out:
#                                               product  \
# 0   Frambozen of Hollandse aardbeien [Kompas JumRo...
# 1           Combikorting fruit [Kompas JumRouterLink]
# 2           Jumbo roerbakmixen [Kompas JumRouterLink]
# 3               Alle Pink Lady [Kompas JumRouterLink]
# 4   Jumbo fijnproevers asperges geschild of witte ...
# ..                                                ...
# 92              Alle Pink Lady [Kompas JumRouterLink]
# 93                     Baileys [Kompas JumRouterLink]
# 94  Licor Beirao, Southern Comfort, Grand Marnier ...
# 95                     Bacardi [Kompas JumRouterLink]
# 96  Welke biermerken zijn bij jouw Jumbo in de aan...
#
#                                discount  \
# 0                           2 voor 6,00
# 1              Combikorting 2 voor 4,50
# 2                           2 voor 3,50
# 3                             voor 2,49
# 4                             voor 4,99
# ..                                  ...
# 92    Alleen in de winkel 2,49 per kilo
# 93  Alleen in de slijterij 4,00 korting
# 94  Alleen in de slijterij 4,00 korting
# 95    Alleen in de slijterij voor 14,99
# 96                       2e halve prijs
#
#                                                  link  store  \
# 0   https://www.jumbo.com/aanbiedingen/frambozen-o...  Jumbo
# 1   https://www.jumbo.com/aanbiedingen/combikortin...  Jumbo
# 2   https://www.jumbo.com/aanbiedingen/jumbo-roerb...  Jumbo
# 3   https://www.jumbo.com/aanbiedingen/alle-pink-l...  Jumbo
# 4   https://www.jumbo.com/aanbiedingen/jumbo-fijnp...  Jumbo
# ..                                                ...    ...
# 92  https://www.jumbo.com/aanbiedingen/alle-pink-l...  Jumbo
# 93  https://www.jumbo.com/aanbiedingen/baileys/301...  Jumbo
# 94  https://www.jumbo.com/aanbiedingen/licor-beira...  Jumbo
# 95  https://www.jumbo.com/aanbiedingen/bacardi/301...  Jumbo
# 96        https://www.jumbo.com/acties/bieraanbieding  Jumbo
#
#                  date
# 0       6 t/m  12 mei
# 1       6 t/m  12 mei
# 2       6 t/m  12 mei
# 3       6 t/m  12 mei
# 4       6 t/m  12 mei
# ..                ...
# 92      6 t/m  12 mei
# 93      6 t/m  12 mei
# 94      6 t/m  12 mei
# 95      6 t/m  12 mei
# 96  4 feb t/m  30 dec
#
# [97 rows x 5 columns]

# %%
df["date"] = df["date"].str.split("t/m")

def split_date(date_val):

    if isinstance(date_val, list):
        cleaned = ' '.join(str(x) for x in date_val)
    else:
        cleaned = str(date_val)

    cleaned = cleaned.replace('\xa0', ' ').replace('NBSP', '').strip()
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()

    same_month = re.match(r'(\d+)\s+(\d+)\s+(\w+)', cleaned)
    if same_month:
        day1, day2, month = same_month.groups()
        return f"{day1} {month}", f"{day2} {month}"

    diff_month = re.match(r'(\d+)\s+(\w+)\s+(\d+)\s+(\w+)', cleaned)
    if diff_month:
        day1, month1, day2, month2 = diff_month.groups()
        return f"{day1} {month1}", f"{day2} {month2}"

    return cleaned, cleaned

df[['start_date', 'end_date']] = df['date'].apply(
    lambda x: pd.Series(split_date(x))
)
# Out:
#              date start_date end_date
# 0  [6 ,   12 mei]      6 mei   12 mei
# 1  [6 ,   12 mei]      6 mei   12 mei
# 2  [6 ,   12 mei]      6 mei   12 mei
# 3  [6 ,   12 mei]      6 mei   12 mei
# 4  [6 ,   12 mei]      6 mei   12 mei
# 5  [6 ,   12 mei]      6 mei   12 mei
# 6  [6 ,   12 mei]      6 mei   12 mei
# 7  [6 ,   12 mei]      6 mei   12 mei
# 8  [6 ,   19 mei]      6 mei   19 mei
# 9  [6 ,   12 mei]      6 mei   12 mei

# %%
df = df.drop("date", axis=1)
df
# Out:
#                                               product  \
# 0   Frambozen of Hollandse aardbeien [Kompas JumRo...
# 1           Combikorting fruit [Kompas JumRouterLink]
# 2           Jumbo roerbakmixen [Kompas JumRouterLink]
# 3               Alle Pink Lady [Kompas JumRouterLink]
# 4   Jumbo fijnproevers asperges geschild of witte ...
# ..                                                ...
# 92              Alle Pink Lady [Kompas JumRouterLink]
# 93                     Baileys [Kompas JumRouterLink]
# 94  Licor Beirao, Southern Comfort, Grand Marnier ...
# 95                     Bacardi [Kompas JumRouterLink]
# 96  Welke biermerken zijn bij jouw Jumbo in de aan...
#
#                                discount  \
# 0                           2 voor 6,00
# 1              Combikorting 2 voor 4,50
# 2                           2 voor 3,50
# 3                             voor 2,49
# 4                             voor 4,99
# ..                                  ...
# 92    Alleen in de winkel 2,49 per kilo
# 93  Alleen in de slijterij 4,00 korting
# 94  Alleen in de slijterij 4,00 korting
# 95    Alleen in de slijterij voor 14,99
# 96                       2e halve prijs
#
#                                                  link  store start_date  \
# 0   https://www.jumbo.com/aanbiedingen/frambozen-o...  Jumbo      6 mei
# 1   https://www.jumbo.com/aanbiedingen/combikortin...  Jumbo      6 mei
# 2   https://www.jumbo.com/aanbiedingen/jumbo-roerb...  Jumbo      6 mei
# 3   https://www.jumbo.com/aanbiedingen/alle-pink-l...  Jumbo      6 mei
# 4   https://www.jumbo.com/aanbiedingen/jumbo-fijnp...  Jumbo      6 mei
# ..                                                ...    ...        ...
# 92  https://www.jumbo.com/aanbiedingen/alle-pink-l...  Jumbo      6 mei
# 93  https://www.jumbo.com/aanbiedingen/baileys/301...  Jumbo      6 mei
# 94  https://www.jumbo.com/aanbiedingen/licor-beira...  Jumbo      6 mei
# 95  https://www.jumbo.com/aanbiedingen/bacardi/301...  Jumbo      6 mei
# 96        https://www.jumbo.com/acties/bieraanbieding  Jumbo      4 feb
#
#    end_date
# 0    12 mei
# 1    12 mei
# 2    12 mei
# 3    12 mei
# 4    12 mei
# ..      ...
# 92   12 mei
# 93   12 mei
# 94   12 mei
# 95   12 mei
# 96   30 dec
#
# [97 rows x 6 columns]

# %%
def product_clean(text):
    word = "[Kompas JumRouterLink]"
    text = text.replace(word, "").strip()
    return text

df["product"] = df["product"].apply(product_clean)
df
# Out:
#                                               product  \
# 0                    Frambozen of Hollandse aardbeien
# 1                                  Combikorting fruit
# 2                                  Jumbo roerbakmixen
# 3                                      Alle Pink Lady
# 4   Jumbo fijnproevers asperges geschild of witte ...
# ..                                                ...
# 92                                     Alle Pink Lady
# 93                                            Baileys
# 94  Licor Beirao, Southern Comfort, Grand Marnier ...
# 95                                            Bacardi
# 96  Welke biermerken zijn bij jouw Jumbo in de aan...
#
#                                discount  \
# 0                           2 voor 6,00
# 1              Combikorting 2 voor 4,50
# 2                           2 voor 3,50
# 3                             voor 2,49
# 4                             voor 4,99
# ..                                  ...
# 92    Alleen in de winkel 2,49 per kilo
# 93  Alleen in de slijterij 4,00 korting
# 94  Alleen in de slijterij 4,00 korting
# 95    Alleen in de slijterij voor 14,99
# 96                       2e halve prijs
#
#                                                  link  store start_date  \
# 0   https://www.jumbo.com/aanbiedingen/frambozen-o...  Jumbo      6 mei
# 1   https://www.jumbo.com/aanbiedingen/combikortin...  Jumbo      6 mei
# 2   https://www.jumbo.com/aanbiedingen/jumbo-roerb...  Jumbo      6 mei
# 3   https://www.jumbo.com/aanbiedingen/alle-pink-l...  Jumbo      6 mei
# 4   https://www.jumbo.com/aanbiedingen/jumbo-fijnp...  Jumbo      6 mei
# ..                                                ...    ...        ...
# 92  https://www.jumbo.com/aanbiedingen/alle-pink-l...  Jumbo      6 mei
# 93  https://www.jumbo.com/aanbiedingen/baileys/301...  Jumbo      6 mei
# 94  https://www.jumbo.com/aanbiedingen/licor-beira...  Jumbo      6 mei
# 95  https://www.jumbo.com/aanbiedingen/bacardi/301...  Jumbo      6 mei
# 96        https://www.jumbo.com/acties/bieraanbieding  Jumbo      4 feb
#
#    end_date
# 0    12 mei
# 1    12 mei
# 2    12 mei
# 3    12 mei
# 4    12 mei
# ..      ...
# 92   12 mei
# 93   12 mei
# 94   12 mei
# 95   12 mei
# 96   30 dec
#
# [97 rows x 6 columns]

# %%
#removing products which are online or liquor store
df = df[~df["discount"].str.contains("Alleen online", case=True, na=False)]
df = df[~df["discount"].str.contains("slijterij", case=True, na=False)]
df = df[df['product'] != 'Welke biermerken zijn bij jouw Jumbo in de aanbieding?']

# %%
df
# Out:
#                                               product  \
# 0                    Frambozen of Hollandse aardbeien
# 1                                  Combikorting fruit
# 2                                  Jumbo roerbakmixen
# 3                                      Alle Pink Lady
# 4   Jumbo fijnproevers asperges geschild of witte ...
# ..                                                ...
# 87                           Alle Marcel's Green Soap
# 88           Alle Robijn wasverzachters of wasparfums
# 89               Alle Witte Reus of Fleuril wasmiddel
# 91                                Zespri Sungold kiwi
# 92                                     Alle Pink Lady
#
#                                  discount  \
# 0                             2 voor 6,00
# 1                Combikorting 2 voor 4,50
# 2                             2 voor 3,50
# 3                               voor 2,49
# 4                               voor 4,99
# ..                                    ...
# 87                             1+1 gratis
# 88                             1+1 gratis
# 89                             2+3 gratis
# 91  Alleen in de winkel 2,79 per 500 gram
# 92      Alleen in de winkel 2,49 per kilo
#
#                                                  link  store start_date  \
# 0   https://www.jumbo.com/aanbiedingen/frambozen-o...  Jumbo      6 mei
# 1   https://www.jumbo.com/aanbiedingen/combikortin...  Jumbo      6 mei
# 2   https://www.jumbo.com/aanbiedingen/jumbo-roerb...  Jumbo      6 mei
# 3   https://www.jumbo.com/aanbiedingen/alle-pink-l...  Jumbo      6 mei
# 4   https://www.jumbo.com/aanbiedingen/jumbo-fijnp...  Jumbo      6 mei
# ..                                                ...    ...        ...
# 87  https://www.jumbo.com/aanbiedingen/alle-marcel...  Jumbo      6 mei
# 88  https://www.jumbo.com/aanbiedingen/alle-robijn...  Jumbo      6 mei
# 89  https://www.jumbo.com/aanbiedingen/alle-witte-...  Jumbo      6 mei
# 91  https://www.jumbo.com/aanbiedingen/zespri-sung...  Jumbo      6 mei
# 92  https://www.jumbo.com/aanbiedingen/alle-pink-l...  Jumbo      6 mei
#
#    end_date
# 0    12 mei
# 1    12 mei
# 2    12 mei
# 3    12 mei
# 4    12 mei
# ..      ...
# 87   19 mei
# 88   19 mei
# 89   12 mei
# 91   12 mei
# 92   12 mei
#
# [79 rows x 6 columns]

# %%
df.to_json('data/J_cleaned_2.json', orient='records', indent=4, force_ascii=False)
